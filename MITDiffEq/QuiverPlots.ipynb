# %% [markdown]
# # Geometric view point on differential equations

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate

# %%
#inspired by http://systems-sciences.uni-graz.at/etextbook/sw3/multivariate.html
def dydx(x,y):
    return y/x

# define dimensions for grid
u = np.linspace(-10, 10,25)
v = np.linspace(-10, 10, 25)
# create grid
x, y  = np.meshgrid(u, v)
print(x.shape)

dy=dydx(x,y)


dx=x

soln=integrate.odeint(dydx,y0=[10],t=u)

plt.figure(figsize=(10, 10))
plt.quiver(x,y,dx,dy)
plt.plot(u,soln.flatten())
# Out:
# (25, 25)
# /home/maria/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/maria/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#inspired by http://systems-sciences.uni-graz.at/etextbook/sw3/multivariate.html
def dydx(x,y):
    return x-y**2

# define dimensions for grid
u = np.linspace(-10, 10,25)
v = np.linspace(-10, 10, 25)
# create grid
x, y  = np.meshgrid(u, v)
print(x.shape)

dy=dydx(x,y)


dx=x

soln=integrate.odeint(dydx,y0=[1],t=u)

plt.figure(figsize=(10, 10))
plt.quiver(x,y,dx,dy)
#plt.plot(u,soln.flatten())
# Out:
# (25, 25)

# %%
#inspired by http://systems-sciences.uni-graz.at/etextbook/sw3/multivariate.html
def dydx(x,y):
    return y-x**2

# define dimensions for grid
u = np.linspace(-10, 10,25)
v = np.linspace(-10, 10, 25)
# create grid
x, y  = np.meshgrid(u, v)
print(x.shape)

dy=dydx(x,y)


dx=x

soln=integrate.odeint(dydx,y0=[1],t=u)

plt.figure(figsize=(10, 10))
plt.quiver(x,y,dx,dy)
# Out:
# (25, 25)
